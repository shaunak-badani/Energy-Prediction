# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import pickle

# %%
model = keras.models.load_model('./EP')
history = pickle.load(open('./trainHistoryDict', "rb"))

# %%
history['epoch'].tail()
# Out:
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# Name: epoch, dtype: int64

# %%
def plot_loss(history):
    plt.plot(history['loss'], label='loss')
    plt.plot(history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error [Energy Values]')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %%
test_data = np.load('test_data.npy')
test_labels = np.load('test_labels.npy')

test_prediction = model.predict(test_data)

# %%
plt.scatter(np.arange(test_labels.shape[0]), test_labels, label='Label Values', s = 2)
plt.scatter(np.arange(test_prediction.shape[0]), test_prediction, label='Prediction values', alpha = 0.2, s = 2)

plt.xlabel('Test Data points')
plt.ylabel('Energy Values')
plt.legend()
plt.grid(True)
